# %%
import torch 
print(torch.cuda.is_available())

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached lm_eval-0.4.8-py3-none-any.whl.metadata (50 kB)
# ...
#   Using cached accelerate-0.34.2-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached antlr4_python3_runtime-4.11.0-py3-none-any.whl.metadata (291 bytes)
# ...
#   Using cached math_verify-0.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# ...
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached gradio-6.3.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-2.4.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...

# %%
# !python llada/chat.py -use_cache
